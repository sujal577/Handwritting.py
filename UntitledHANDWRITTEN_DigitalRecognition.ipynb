# %%
# fetching dataset
from sklearn.datasets import fetch_openml
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

mnist = fetch_openml('mnist_784')

# %%
# fetching dataset
from sklearn.datasets import fetch_openml
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

mnist = fetch_openml('mnist_784')

# %%
x, y = mnist['data'], mnist['target']

some_digit = x.to_numpy()[36001]
some_digit_image = some_digit.reshape(28, 28)  # let's reshape to plot it

plt.imshow(some_digit_image, cmap=matplotlib.cm.binary,
           interpolation='nearest')
plt.axis("off")
plt.show()

# %%
y[36001]
# Out:
# '2'

# %%
x_train, x_test = x[:60000], x[60000:]

# %%
y_train, y_test = y[:60000], y[60000:]

# %%
import numpy as np

# Ensure x_train and y_train are NumPy arrays
x_train = np.array(x_train)  # Convert to NumPy array if not already
y_train = np.array(y_train)  # Convert to NumPy array if not already

shuffle_index = np.random.permutation(60000)  # Generate a random permutation of indices
x_train, y_train = x_train[shuffle_index], y_train[shuffle_index]  # Shuffle the datasets

# %%
y_train = y_train.astype(np.int8)
y_test = y_test.astype(np.int8)
y_train_2 = (y_train==2)
y_test_2 = (y_test==2)

# %%
y_train
# Out:
# array([9, 8, 8, ..., 4, 4, 8], dtype=int8)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(tol = 0.1)

# %%
clf.fit(x_train, y_train_2)
# Out:
# LogisticRegression(tol=0.1)

# %%
clf.predict([some_digit])
# Out:
# array([ True])

# %%
from sklearn.model_selection import cross_val_score
a = cross_val_score(clf, x_train, y_train_2, cv=3, scoring="accuracy")

# %%
a.mean()
# Out:
# 0.97905
